# %%
# import necessary libraries and packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# I need to join some of the respective datasets together. But fitst lets load them and check that they can be matched up.

# %%
# First i think join driver name (in drivers.csv) to driver id (on results.csv). This will make it less confusing. I then want to join 
# constructor name (in constructors.csv) to constructor id (in results.csv). Finally I want to join race id (in races.csv)
# to the overall dataset. This will give me all the information I need in one dataframe for now.

# Load results data
results = pd.read_csv('data_raw/results.csv')

# Load driver metadata, selecting and renaming to avoid name collisions
drivers = pd.read_csv('data_raw/drivers.csv')[['driverId', 'forename', 'surname', 'nationality']]
# create new column for full name
drivers['driverName'] = drivers['forename'] + ' ' + drivers['surname']
drivers = drivers[['driverId', 'driverName', 'nationality']]

# Merge driver info into results (avoid duplicate columns by using merge)
overall = results.merge(drivers, on='driverId', how='inner')

# Load constructor and race metadata, selecting and renaming to avoid name collisions (this is all we need from these two csvs)
constructors = pd.read_csv('data_raw/constructors.csv')[['constructorId', 'name']].rename(columns={'name': 'constructorName'})
races = pd.read_csv('data_raw/races.csv')[['raceId', 'year', 'round', 'name']].rename(columns={'name': 'raceName'})

# Merge constructors and races into the overall dataset
overall = overall.merge(constructors, on='constructorId', how='left').merge(races, on='raceId', how='left')

display(overall)
# Out:
#        resultId  raceId  driverId  constructorId number  grid position  \
# 0             1      18         1              1     22     1        1
# 1             2      18         2              2      3     5        2
# 2             3      18         3              3      7     7        3
# 3             4      18         4              4      5    11        4
# 4             5      18         5              1     23     3        5
# ...         ...     ...       ...            ...    ...   ...      ...
# 26754     26760    1144       825            210     20    14       16
# 26755     26761    1144       859            215     30    12       17
# 26756     26762    1144       822             15     77     9       \N
# 26757     26763    1144       861              3     43    20       \N
# 26758     26764    1144       815              9     11    10       \N
#
#       positionText  positionOrder  points  ...  rank fastestLapTime  \
# ...

# %% [markdown]
# Im going to also merge the statusId dataframe to the main one because this could make interesting analysis later

# %%
race_status = pd.read_csv('data_raw/status.csv')

overall = overall.merge(race_status, on='statusId', how='inner')

# Get current columns
cols = list(overall.columns)

# Specify which column you want to move to index 10
column_to_move = 'status'  # Replace with your column name

# Remove the column from its current position
cols.remove(column_to_move)

# Insert it at index 10
cols.insert(12, column_to_move)

# Reorder the dataframe
overall = overall[cols]

# Drop statusId as we no longer need it
overall.drop(columns=['statusId'], inplace=True)

overall.head(20)
# Out:
#     resultId  raceId  driverId  constructorId number  grid position  \
# 0          1      18         1              1     22     1        1
# 1          2      18         2              2      3     5        2
# 2          3      18         3              3      7     7        3
# 3          4      18         4              4      5    11        4
# 4          5      18         5              1     23     3        5
# 5          6      18         6              3      8    13        6
# 6          7      18         7              5     14    17        7
# 7          8      18         8              6      1    15        8
# 8          9      18         9              2      4     2       \N
# 9         10      18        10              7     12    18       \N
# 10        11      18        11              8     18    19       \N
# 11        12      18        12              4      6    20       \N
# 12        13      18        13              6      2     4       \N
# ...

# %% [markdown]
# This dataframe looks good! much easier to navigate. Not sure why it starts at 2008 so ill order it based on year.

# %%
# Sort by year, round and numeric finishing order
overall = overall.sort_values(by=['year', 'round', 'positionOrder']).set_index('raceId')
overall
# Out:
#         resultId  driverId  constructorId number  grid position positionText  \
# raceId
# 833        20025       642             51      2     1        1            1
# 833        20026       786             51      3     2        2            2
# 833        20027       686             51      4     4        3            3
# 833        20028       704            154     14     6        4            4
# 833        20029       627            154     15     9        5            5
# ...          ...       ...            ...    ...   ...      ...          ...
# 1144       26760       825            210     20    14       16           16
# 1144       26761       859            215     30    12       17           17
# 1144       26762       822             15     77     9       \N            R
# 1144       26763       861              3     43    20       \N            R
# 1144       26764       815              9     11    10       \N            R
#
# ...

# %% [markdown]
# This is now a neat dataframe sorted by year and in order of round and position that the drivers finished in the race

# %% [markdown]
# ### Readjusting the points allocation using modern scoring system

# %% [markdown]
# The points systems in the past have been as follows:
# - 1950–1959: 8–6–4–3–2, top 5 (fastest lap +1)
# - 1960–1990: 9–6–4–3–2–1, top 6 (no fastest lap)
# - 1991–2002: 10–6–4–3–2–1, top 6 (no fastest lap)
# - 2003–2009: 10–8–6–5–4–3–2–1, top 8 (no fastest lap)
# - 2010–2018: 25–18–15–12–10–8–6–4–2–1, top 10 (no fastest lap)
# - 2019–present: 25–18–15–12–10–8–6–4–2–1, top 10 (fastest lap +1, top 10 only)
#
# The best set of points to use would be the most recent method of scoring points, from 52-1 for the top 10.
#
# No need to include an if conditon just in case there wasnt a top 10 that finished (e.g.Panis monaco 1996!!).
#
# In F1, points are awarded purely by classified finishing order, not by whether a driver was running at the end. Monaco 1996 is the perfect example: only 3 cars finished, but points were still awarded down the order of classification.

# %%
# im going to map the modern points to position and then replace them directly.
modern_points = {
    1: 25,
    2: 18,
    3: 15,
    4: 12,
    5: 10,
    6: 8,
    7: 6,
    8: 4,
    9: 2,
    10: 1
}

# Wrote this but no need to include it!!
# overall['points'] = np.where(overall['positionOrder'].map(modern_points).notnull(), # check if they finished
#                              overall['positionOrder'].map(modern_points), 0)

overall.insert(
    9,  # column index (0 = first)
    'modern_points',
    overall['positionOrder']
        .map(modern_points)
        .fillna(0)
        .astype(float)
)

overall.head(20)
# Out:
#         resultId  driverId  constructorId number  grid position positionText  \
# raceId
# 833        20025       642             51      2     1        1            1
# 833        20026       786             51      3     2        2            2
# 833        20027       686             51      4     4        3            3
# 833        20028       704            154     14     6        4            4
# 833        20029       627            154     15     9        5            5
# 833        20030       619            151     12    13        6            6
# 833        20031       787            151     11    15        7            7
# 833        20032       741            154     16    14        8            8
# 833        20033       784            105      6    16        9            9
# 833        20034       778            105     10    20       10           10
# 833        20177       788            105     10    20       10           10
# ...

# %%
overall.dtypes
# year is int64 and raceName is object (string)

# Lets look at 1996 as an example to see if my mapping worked
overall[(overall['year'] == 1996) & (overall['raceName'] == 'Monaco Grand Prix')]
# Out:
#         resultId  driverId  constructorId number  grid position positionText  \
# raceId
# 229         4491        44             27      9    14        1            1
# 229         4492        14              1      8     5        2            2
# 229         4493        65             15     14    13        3            3
# 229         4494        49             15     15     9        4            4
# 229         4495        63             25     19    11        5            5
# 229         4496        57              1      7     8        6            6
# 229         4497        56              6      2     7        7            7
# 229         4498        35              3      6    10       \N            R
# 229         4499        55             22      3     3       \N            R
# 229         4500        69             28     22    21       \N            R
# 229         4501        71              3      5     2       \N            R
# ...

# %% [markdown]
# ## (Slide 1) How consistently do people overperform and underperform in qulifying vs race. who are the biggest overperformers?

# %% [markdown]
# we need to make a column for positions gained. One issue may be DNFs or retirements. To calculate these take (total amount of racers - starting position on grid). Looks like 'positionOrder' takes into account retirements so thats handy! This should allow me to calculate positions lost including DNFs or DSQs.

# %%
# check that the columns are integers
print(overall['positionOrder'].dtype)
print(overall['grid'].dtype)
# Out:
# int64
# int64

# %%
# positions gained = grid - finishing order; handle unknown grid (0) as NaN
# use np.where() to be the value arg in .insert(). we want to insert after 'positionOrder' column.
overall.insert(6, 'positions_gained_or_lost', np.where(overall['grid'] > 0, overall['grid'] - overall['positionOrder'], np.nan))
overall
# Out:
#         resultId  driverId  constructorId number  grid position  \
# raceId
# 833        20025       642             51      2     1        1
# 833        20026       786             51      3     2        2
# 833        20027       686             51      4     4        3
# 833        20028       704            154     14     6        4
# 833        20029       627            154     15     9        5
# ...          ...       ...            ...    ...   ...      ...
# 1144       26760       825            210     20    14       16
# 1144       26761       859            215     30    12       17
# 1144       26762       822             15     77     9       \N
# 1144       26763       861              3     43    20       \N
# 1144       26764       815              9     11    10       \N
#
#         positions_gained_or_lost positionText  positionOrder  points  ...  \
# raceId                                                                ...
# ...

# %% [markdown]
# Probably a good idea to add average qualifying position and average finishing position

# %%
overall['avg_qualifying_pos'] = overall.groupby('driverId')['grid'].transform('mean').round(3)
overall['avg_finishing_pos'] = overall.groupby('driverId')['positionOrder'].transform('mean').round(3)

overall.head(20)
# Out:
#         resultId  driverId  constructorId number  grid position  \
# raceId
# 833        20025       642             51      2     1        1
# 833        20026       786             51      3     2        2
# 833        20027       686             51      4     4        3
# 833        20028       704            154     14     6        4
# 833        20029       627            154     15     9        5
# 833        20030       619            151     12    13        6
# 833        20031       787            151     11    15        7
# 833        20032       741            154     16    14        8
# 833        20033       784            105      6    16        9
# 833        20034       778            105     10    20       10
# 833        20177       788            105     10    20       10
# 833        20035       660            154     18    21       11
# 833        20036       579             51      1     3       \N
# ...

# %% [markdown]
# Now we need to find out who gained most positions on average. Divide by number or races that the raced in.

# %%
# Average positions gained/lost per race, including new columns
positions_summary = (
    overall.groupby('driverName')
    .agg(
        total_positions=('positions_gained_or_lost', 'sum'),
        races=('positions_gained_or_lost', 'count'),
        avg_qualifying_pos=('avg_qualifying_pos', 'mean'),
        avg_finishing_pos=('avg_finishing_pos', 'mean')
    )
    .assign(avg_positions_per_race=lambda x: x['total_positions'] / x['races']).round(3)
    .round(3) # round all numeric columns to 3 decimal places
    .sort_values(by='avg_positions_per_race', ascending=False)
    .reset_index()
)

positions_summary
# Out:
#           driverName  total_positions  races  avg_qualifying_pos  \
# 0       George Amick             23.0      1                25.0
# 1     Bud Tingelstad             19.0      1                28.0
# 2      Ernst Klodwig             34.0      2                30.5
# 3       Carl Forberg             17.0      1                24.0
# 4    Renato Pirocchi             17.0      1                14.5
# ..               ...              ...    ...                 ...
# 856    Ted Whiteaway              0.0      0                 0.0
# 857   Thomas Monarch              0.0      0                 0.0
# 858        Tom Jones              0.0      0                 0.0
# 859     Tony Trimmer              0.0      0                 0.0
# 860   Volker Weidler              0.0      0                 0.0
#
#      avg_finishing_pos  avg_positions_per_race
# 0                2.000                    23.0
# 1                9.000                    19.0
# ...

# %% [markdown]
# Some very cool stats here. George Amick only raced one race in his entire f1 career and went from 25 starting position to a podium finish. This was using no minimum races raced. Im going to change this to at least 10 races raced and five races raced.

# %%
positions_summary.loc[positions_summary['races'] >= 10]
# Out:
#                 driverName  total_positions  races  avg_qualifying_pos  \
# 25            Pascal Fabre            121.0     11              22.833
# 38            Slim Borgudd             97.0     10              15.133
# 43            Patrick Nève             94.0     10              17.538
# 60            Alex Ribeiro             88.0     10              10.750
# 64           Stefan Bellof            170.0     20              19.864
# ..                     ...              ...    ...                 ...
# 746    Eugenio Castellotti            -79.0     17               4.882
# 748           Ayrton Senna           -803.0    161               3.130
# 760       Michael Andretti            -74.0     13               9.769
# 766            Andy Linden            -69.0     11              12.545
# 767  Jean-Pierre Jabouille           -326.0     49               8.455
#
#      avg_finishing_pos  avg_positions_per_race
# 25              15.083                  11.000
# ...

# %%
highest_overperformers = positions_summary.loc[positions_summary['races'] >= 100].copy()

# %% [markdown]
# I also want to include most positions gained at a certain race. Ill have to group by race and driver then filter for at least 5 races. Then i can calculate the average positions gained

# %%
# driver–race pairs: average positions gained at that race (min 10 participations)
pos_gained_race = (
    overall
    .dropna(subset=['positions_gained_or_lost'])    # ensure we only consider races where positions gained/lost is known
    .groupby(['driverName', 'raceName'], as_index=False)  # group by driver and race
    .agg(
        races=('positions_gained_or_lost', 'count'),
        total_positions=('positions_gained_or_lost', 'sum'),
        avg_positions_per_race=('positions_gained_or_lost', 'mean'),
        avg_qualifying_pos=('avg_qualifying_pos', 'mean'),
        avg_finishing_pos=('avg_finishing_pos', 'mean')
    )
    .sort_values('avg_positions_per_race', ascending=False)
    .round(3)
    .reset_index(drop=True)
)

highest_circuit_overperformers = pos_gained_race.loc[pos_gained_race['races'] >= 10]
highest_circuit_overperformers
# Out:
#                 driverName                  raceName  races  total_positions  \
# 964         Martin Brundle     San Marino Grand Prix     10             66.0
# 1227          Jim Rathmann          Indianapolis 500     12             68.0
# 1234           John Watson       Austrian Grand Prix     10             56.0
# 1300    Emerson Fittipaldi         Monaco Grand Prix     10             53.0
# 1529  Giancarlo Fisichella        British Grand Prix     14             67.0
# ...                    ...                       ...    ...              ...
# 6614        Gerhard Berger        Belgian Grand Prix     13            -98.0
# 6622          Ayrton Senna     San Marino Grand Prix     10            -77.0
# 6662          Ayrton Senna      Brazilian Grand Prix     11            -91.0
# 6677        Mario Andretti  United States Grand Prix     10            -86.0
# 6680          Ayrton Senna         French Grand Prix     10            -87.0
#
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as mcolors

fig, ax = plt.subplots(1, 2, figsize=(12, 5))

# create the subset if it doesn't already exist
if 'highest_overperformers' not in globals():
	highest_overperformers = positions_summary.loc[positions_summary['races'] >= 100].copy()

##### scatter plot of average qualifying vs average finishing positions #####
sc = ax[0].scatter(
    highest_overperformers['avg_qualifying_pos'],
    highest_overperformers['avg_finishing_pos'],
    c=highest_overperformers['avg_positions_per_race'],
    cmap='viridis',      # perceptually uniform, colour-blind safe
    alpha=0.8
)

# Get top 2 and bottom 2 performers
top_2 = highest_overperformers.nlargest(2, 'avg_positions_per_race')
bottom_2 = highest_overperformers.nsmallest(2, 'avg_positions_per_race')
to_annotate = pd.concat([top_2, bottom_2])


# Overlay annotated points in a different colour
ax[0].scatter(
    to_annotate['avg_qualifying_pos'],
    to_annotate['avg_finishing_pos'],
    c=to_annotate['avg_positions_per_race'],
    cmap='viridis',      # perceptually uniform, colour-blind safe
    s=60,                 # bigger points
    edgecolors='black',   # makes the points stand out more
    zorder=3
)

# Annotate only these drivers
for idx, row in to_annotate.iterrows():
    ax[0].annotate(
        f"{row['driverName']}\n{row['avg_positions_per_race']:.2f}", 
        (row['avg_qualifying_pos'], row['avg_finishing_pos']), 
        textcoords="offset points", 
        xytext=(4, 4), 
        ha="left", 
        fontsize=8,
        bbox=dict(boxstyle="round,pad=0.3", facecolor="white", alpha=0.7)
    )

ax[0].set_xlabel('Average qualifying position')
ax[0].set_ylabel('Average finishing position')
ax[0].set_title('Qualifying vs Finishing (drivers with ≥ 100 races)')


##### scatter plot of average qualifying vs average finishing positions #####

if 'highest_circuit_overperformers' not in globals():
      highest_circuit_overperformers = pos_gained_race.loc[pos_gained_race['races'] >= 10]

##### scatter plot of average qualifying vs average finishing positions #####
sc = ax[1].scatter(
    highest_circuit_overperformers['avg_qualifying_pos'],
    highest_circuit_overperformers['avg_finishing_pos'],
    c=highest_circuit_overperformers['avg_positions_per_race'],
    cmap='viridis',      # perceptually uniform, colour-blind safe
    alpha=0.8
)

# Get top 2 and bottom 2 performers
top_2 = highest_circuit_overperformers.nlargest(2, 'avg_positions_per_race')
bottom_2 = highest_circuit_overperformers.nsmallest(2, 'avg_positions_per_race')
to_annotate = pd.concat([top_2, bottom_2])

# Overlay annotated points in a different colour
ax[1].scatter(
    to_annotate['avg_qualifying_pos'],
    to_annotate['avg_finishing_pos'],
    c=to_annotate['avg_positions_per_race'],
    cmap='viridis',      # perceptually uniform, colour-blind safe
    s=60,                 # bigger points
    edgecolors='black',   # makes the points stand out more
    zorder=3
)

for idx, row in to_annotate.iterrows():

    # Defaults (current behavior)
    xytext = (4, 4)
    ha = "left"
    va = "bottom"

    # Custom placements
    if row['driverName'] == "Mario Andretti":
        xytext = (-4, 4)     # top-left
        ha = "right"
        va = "bottom"

    elif row['driverName'] == "Jim Rathmann":
        xytext = (-4, -4)    # bottom-left
        ha = "right"
        va = "top"

    ax[1].annotate(
        f"{row['driverName']}\n{row['raceName']}\n{row['avg_positions_per_race']:.2f}",
        (row['avg_qualifying_pos'], row['avg_finishing_pos']),
        textcoords="offset points",
        xytext=xytext,
        ha=ha,
        va=va,
        fontsize=8,
        bbox=dict(
            boxstyle="round,pad=0.3",
            facecolor="white",
            alpha=0.7
        )
    )


ax[1].set_xlabel('Average qualifying position')
ax[1].set_ylabel('Average finishing position')
ax[1].set_title('Qualifying vs Finishing (driver–race pairs with ≥ 10 participations)')
# Out:
# Text(0.5, 1.0, 'Qualifying vs Finishing (driver–race pairs with ≥ 10 participations)')

# %%
# save the figure for slide 1
fig.savefig('figures/qual_vs_finish_overperformers.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# ## (Unused graph) top 15 and bottom 15 over and underperformers

# %% [markdown]
# I was going to use this graph, but i decided agaist it due to the fact that it tells the same story as the last slides' scattergraph of under and overperformers. I will still leave it in the notebook though.

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 5))

##### Bar chart: top 5 by avg positions gained per race #####
top_n = highest_overperformers.nlargest(15, 'avg_positions_per_race')

# Normalise values for colormap
norm = mcolors.Normalize(
    vmin=top_n['avg_positions_per_race'].min(),
    vmax=top_n['avg_positions_per_race'].max()
)

colors = cm.viridis(norm(top_n['avg_positions_per_race']))

ax[0].bar(
    top_n['driverName'],
    top_n['avg_positions_per_race'],
    color=colors
)

ax[0].set_xlabel('Driver')
ax[0].set_ylabel('Avg positions gained per race')
ax[0].set_title('Top 15 overperformers (≥ 100 races)')
ax[0].tick_params(axis='x', rotation=60)

##### Bar chart: top 15 by avg positions gained per race #####
bottom_n = highest_overperformers.nsmallest(15, 'avg_positions_per_race')

# Normalise values for colormap
norm = mcolors.Normalize(
    vmin=bottom_n['avg_positions_per_race'].min(),
    vmax=bottom_n['avg_positions_per_race'].max()
)

colors = cm.viridis(norm(bottom_n['avg_positions_per_race']))

ax[1].bar(
    bottom_n['driverName'],
    abs(bottom_n['avg_positions_per_race']), # use abs to show positive bars
    color=colors
)

ax[1].set_xlabel('Driver')
ax[1].set_ylabel('Avg positions lost per race')
ax[1].set_yticklabels([0, -1, -2, -3, -4, -5])
ax[1].set_title('Top 15 underperformers (≥ 100 races)')
ax[1].tick_params(axis='x', rotation=60)

plt.tight_layout()
# Out:
# /var/folders/r8/fbhf1t_d7lq51r88zz03_blr0000gn/T/ipykernel_70694/1263371321.py:44: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_yticklabels([0, -1, -2, -3, -4, -5])

# %%
# I find it interesting that senna has a negative average finishing position despite being one of the greatest drivers of all time.
# This is likely due to his aggressive driving style which often led to retirements. Lets cound how many retoirements he had as a
# proportion of races he entered.

retirement_statuses = overall['status'].unique().tolist()

# manually create the list. easier than making the series into a list then looping to remove +n laps.
retirement_statuses = [
    'Oil leak', 'Not classified', 'Out of fuel', 
    'Engine', 'Transmission', 'Clutch', 'Oil pressure', 'Gearbox', 'Supercharger', 'Axle', 'Accident', 
    'Collision', 'Spun off', 'Oil line', 'Wheel bearing', 'Stalled', 'Suspension', 'Oil pump', 'Oil pipe', 
    'Overheating', 'Fuel pump', 'Radiator', 'Retired', 'Brakes', 'Water pipe', 'Withdrew', 'Magneto', 
    'Ignition', 'Fuel system', 'Heat shield fire', 'Fuel leak', 'Wheel', 'Halfshaft', 
    'Steering', 'Differential', 'Turbo', 'Exhaust', 'Disqualified', 'Electrical', 'Did not qualify', 
    'Throttle', 'Physical', 'Injection', 'Fuel pressure', 'Tyre', 'Chassis', 
    'Water leak', 'Water pump', 'Distributor', 'Handling', 'Vibrations', 'Puncture', 'Battery', 
    'Driver unwell', 'Did not prequalify', 'Alternator', 'Injury', 'Broken wing', 
    'Fuel pipe', 'Fatal accident', 'Eye injury', 'Injured', 'Mechanical', 'Spark plugs', 'CV joint', 
    'Excluded', 'Driveshaft', 'Hydraulics', 'Fire', 'Safety belt', '107% Rule', 'Fuel', 'Underweight', 
    'Rear wing', 'Safety concerns', 'Not restarted', 'Crankshaft', 'Fuel rig', 'Wheel rim', 'Power loss', 
    'Safety', 'Electronics', 'Drivetrain', 'Launch control', 'Pneumatics', 
    'Engine fire', 'Tyre puncture', 'Wheel nut', 'Technical', 'Track rod', 'Front wing', 'Water pressure', 
    'Refuelling', 'Driver Seat', 'Engine misfire', 'Collision damage', 'ERS', 'Power Unit', 'Brake duct', 
    'Seat', 'Damage', 'Debris', 'Illness', 'Cooling system', 'Undertray'
    ]


# get Senna's data
senna_data = overall[overall['driverName'] == 'Ayrton Senna'].copy()  # make a copy

# create boolean column for retirement using the list i created
senna_data.loc[:, 'retired'] = senna_data['status'].isin(retirement_statuses)

# retirement rate is the mean of the boolean column
retirement_rate = senna_data['retired'].mean()

print(f"Ayrton Senna's retirement rate: {retirement_rate:.2%}")
# Out:
# Ayrton Senna's retirement rate: 40.12%

# %% [markdown]
# ## (Slide 3) Senna and Salo season heatmaps to interpret

# %% [markdown]
# I want to now do a heatmap of sennas finishing positions by each season he competed in, in order to understand why his positions lost were so high

# %%
##### Senna heatmap #####

# Filter data for Ayrton Senna
senna_data = overall[overall['driverName'] == 'Ayrton Senna'].copy()

heatmap_data = (
    senna_data
    .groupby(['year', 'positionOrder'])
    .size()
    .unstack(fill_value=0)
)

fig, ax = plt.subplots(figsize=(12, 6))

im = ax.imshow(
    heatmap_data,
    aspect='auto',
    cmap='magma'   # very close to The Race aesthetic
)

# X ticks
ax.set_xticks(range(len(heatmap_data.columns)))
ax.set_xticklabels(heatmap_data.columns, fontsize=14)

# Y ticks
ax.set_yticks(range(len(heatmap_data.index)))
ax.set_yticklabels(heatmap_data.index, fontsize=14)

# Set labels and title
ax.set_xticklabels(heatmap_data.columns, fontsize=14)
ax.set_yticklabels(heatmap_data.index, fontsize=14)

ax.set_xlabel('Finishing position', fontsize=16)
ax.set_ylabel('Season', fontsize=16)

ax.set_title('Ayrton Senna – Finishing Position Heatmap by Season', fontsize=18, pad=14)

cbar = fig.colorbar(im, ax=ax)
cbar.set_label('Number of races finished in position', fontsize=15)
cbar.ax.tick_params(labelsize=13)

# %%
fig.savefig('figures/senna_heatmap.png', dpi=300, bbox_inches='tight')

# %%
##### Salo heatmap #####

# Filter data for Mika Salo
salo_data = overall[overall['driverName'] == 'Mika Salo'].copy()

heatmap_data = (
    salo_data
    .groupby(['year', 'positionOrder'])
    .size()
    .unstack(fill_value=0)
    .sort_index()   # ensure years are in order
)

fig, ax = plt.subplots(figsize=(12, 6))

im = ax.imshow(
    heatmap_data.values,
    aspect='auto',
    cmap='magma'   # matches Senna heatmap
)

# Make ticks match the heatmap grid
ax.set_xticks(range(len(heatmap_data.columns)))
ax.set_yticks(range(len(heatmap_data.index)))

# Apply labels (larger for slides)
ax.set_xticklabels(heatmap_data.columns, fontsize=14)
ax.set_yticklabels(heatmap_data.index, fontsize=14)

# Axis labels
ax.set_xlabel('Finishing position', fontsize=16)
ax.set_ylabel('Season', fontsize=16)

# Title
ax.set_title('Mika Salo – Finishing Position Heatmap by Season',
             fontsize=18, pad=14)

# colour bar
cbar = fig.colorbar(im, ax=ax)

# Force integer ticks only
max_val = int(heatmap_data.values.max()) # most times finished in that position
cbar.set_ticks(range(0, max_val + 1))
cbar.set_label('Number of races finished in position', fontsize=15)
cbar.ax.tick_params(labelsize=13)


plt.tight_layout()
plt.show()

# %%
fig.savefig('figures/salo_heatmap.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# ## (Slide 4) Could any drivers who never scored points in their careers have scored points if the modern scoring system had been in place? Also who has the most points scored overall using the modern scoring system?

# %% [markdown]
# This one may be interesting to work out. Ill have to load the original dataset again and then aggregate a new table using sum then filtering for drivers that scored 0 points. I can then compare it to the current 'overall' dataframe where the points totals have

# %%
# I ended up adding the modern points column earlier so that it saved me from having to do it later on.
# lets select for drivers who scored 0 points in points column and drivers who do have points in modern points column

missed_out_points = overall[(overall['points'] == 0.0) & (overall['modern_points'] != 0.0)]

missed_out_points
# Out:
#         resultId  driverId  constructorId number  grid position  \
# raceId
# 833        20030       619            151     12    13        6
# 833        20031       787            151     11    15        7
# 833        20032       741            154     16    14        8
# 833        20033       784            105      6    16        9
# 833        20034       778            105     10    20       10
# ...          ...       ...            ...    ...   ...      ...
# 15          7843         4              4      7    16       10
# 16          7862         5              1      2    16        9
# 16          7863       155              7     10    11       10
# 17         16075         3              3     16     9        9
# 17         16076         9              2      5     7       10
#
#         positions_gained_or_lost positionText  positionOrder  points  ...  \
# raceId                                                                ...
# ...

# %% [markdown]
# small problem here is that some drivers did score points but my code is only picking up on the races that they didnt. I need to only select drivers who scored 0 points in their career overall. This table above could be used a potential points missed out graph/metric to be used later!!

# %%
# compute drivers that 
driver_totals = (
    overall
        .groupby('driverName', as_index=False)
        .agg(
            career_points=('points', 'sum'),
            career_modern_points=('modern_points', 'sum')
        )
)

zero_point_drivers = driver_totals[
    (driver_totals['career_points'] == 0) &
    (driver_totals['career_modern_points'] > 0)
]['driverName']

potential_scorers = overall[
    overall['driverName'].isin(zero_point_drivers)
]

potential_scorers
# Out:
#         resultId  driverId  constructorId number  grid position  \
# raceId
# 833        20030       619            151     12    13        6
# 833        20031       787            151     11    15        7
# 833        20033       784            105      6    16        9
# 833        20034       778            105     10    20       10
# 833        20177       788            105     10    20       10
# ...          ...       ...            ...    ...   ...      ...
# 43           540        26              5     19    15       \N
# 44           563        26              5     19    15       \N
# 45           587        26              5     19    18       \N
# 11          7770        69              6      3    20       17
# 12          7787        69              6      3    20       14
#
#         positions_gained_or_lost positionText  positionOrder  points  ...  \
# raceId                                                                ...
# ...

# %%
potential_scorers_order = (
    potential_scorers
        .groupby('driverName', as_index=False)
        .agg(
            first_year=('year', 'min'),
            last_year=('year', 'max'),
            active_seasons=('year', 'nunique'),
            career_span=('year', lambda x: x.max() - x.min() + 1),
            missed_seasons=('year', lambda x: (x.max() - x.min() + 1) - x.nunique()),
            old_points=('points', 'sum'),
            new_points=('modern_points', 'sum'),
            avg_qualifying_pos=('avg_qualifying_pos', 'mean'),
            avg_finishing_pos=('avg_finishing_pos', 'mean')
        )
        .sort_values('new_points', ascending=False)
        .round(3)
        .reset_index(drop=True)
)

potential_scorers_order
# Out:
#          driverName  first_year  last_year  active_seasons  career_span  \
# 0    Yannick Dalmas        1987       1994               5            8
# 1       Luca Badoer        1993       2009               5           17
# 2        Bob Gerard        1950       1957               6            8
# 3      Brian Henton        1975       1982               4            8
# 4      Johnny Claes        1950       1955               5            6
# ..              ...         ...        ...             ...          ...
# 172   Chris Bristow        1959       1960               2            2
# 173     Chuck Daigh        1960       1960               1            1
# 174  Michel Leclère        1975       1976               2            2
# 175   Paolo Barilla        1989       1990               2            2
# 176   Adrián Campos        1987       1988               2            2
#
#      missed_seasons  old_points  new_points  avg_qualifying_pos  \
# ...

# %%
# bar chart looks good but i want to show which years the points were scored in and colour it by that. would drivers have gained more points in different eras?
# need to only include drivers in the df who never scored points.  Ill also include each of their races and the years of the races, so that i can assign different colours to parts of the bar,
# answering the question 'could a driver have socred more points in a certain era than another based on where they finished./what era do most of their points come from?


# First define eras as tuples of (start, end, label)
points_eras = [
    (1950, 1959, "1950-1959"),
    (1960, 1990, "1960-1990"),
    (1991, 2002, "1991-2002"),
    (2003, 2009, "2003-2009"),
    (2010, 2100, "2010+"),
]

def year_to_era(y: int) -> str: # expect int but return str.
    for start, end, label in points_eras:
        if start <= y <= end: # Is y greater than or equal to start and less than or equal to end
            return label
    return "Other"

era_order = [label for _, _, label in points_eras]  # keep legend / stack order consistent

# Ensure we have a year column
df = potential_scorers.copy()

# Assign era and aggregate modern points per driver x era
df["era"] = df["year"].apply(year_to_era)

driver_era_points = (
    df.groupby(["driverName", "era"], as_index=False)["modern_points"]
      .sum()
)

# Pick top 25 drivers to plot by total modern points
# This is a series that will be used as an index. then used in .isin() in next step
top25_idx = (
    driver_era_points.groupby("driverName")["modern_points"].sum() # Group by driver and sum points
    .sort_values(ascending=False) # highest to lowest
    .head(25)
    .index # extract only the index
)


# Pivot to wide format for stacked plotting
# (long)                (wide)
# driver, era, points → driver | era1 | era2 | era3
wide = (
    driver_era_points[driver_era_points["driverName"].isin(top25_idx)] # boolean indexing for 'True'
    .pivot(index="driverName", columns="era", values="modern_points") # pivots so that era becomes columns
    .reindex(columns=era_order)   # enforce era order
    .fillna(0)
)


# Sort drivers by total points
# sum across eras then sort drivers by that total (order currently jumbled)
# extract sorted index which is row order then use .loc[...] to select rows in exactly the order provided
wide = wide.loc[wide.sum(axis=1).sort_values(ascending=False).index]

# %%
wide.columns # checking this in case of hyphon issues when matching the colours dictionary
# Out:
# Index(['1950-1959', '1960-1990', '1991-2002', '2003-2009', '2010+'], dtype='object', name='era')

# %%
presentation_colours = {
    "1950-1959": "#FF7A00",   # Papaya
    "1960-1990": "#FFC857",   # Gold
    "1991-2002": "#C2410C",   # Burnt orange
    "2003-2009": "#111827",   # Near black
    "2010+":     "#6B7280"    # Steel grey
}

# %%
fig, ax = plt.subplots(figsize=(12, 5))

# Plot stacked bars
wide.plot(
    kind="bar",
    stacked=True,
    ax=ax,
    width=0.6,
    color=[presentation_colours[c] for c in wide.columns], # apply respective colours
    edgecolor="black",
    linewidth=1.5   # bold outlines
)

# Ensure x ticks line up with bars
ax.set_xticks(range(len(wide.index)))
ax.set_xticklabels(wide.index, rotation=45, ha="right", fontsize=10)

# Titles and labels
ax.set_title(
    "Drivers with 0 career points (old system): modern points split by era",
    fontsize=16, pad=12
    )
ax.set_ylabel("Modern Points", fontsize=13, fontweight="bold")
ax.set_xlabel("")

# Ticks
ax.tick_params(axis="x", labelsize=10, rotation=45)
ax.tick_params(axis="y", labelsize=11)

# Clean spines
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)

# Subtle gridlines
ax.grid(axis="y", linestyle="-", linewidth=0.6, alpha=0.3)
ax.set_axisbelow(True)

# Legend
ax.legend(
    title="Era",
    fontsize=10,
    title_fontsize=11,
    frameon=False,
    bbox_to_anchor=(1.02, 1),
    loc="upper left"
)

fig.tight_layout()
plt.show()

# %%
fig.savefig('figures/zero_point_drivers_by_era.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# ## (slide 5) Era dominance. How dominant was this driver relative to the races available in their era?

# %%
# check that overall dataframe is still intact
# overall.head()

# need to make a mapping dict for eras
# apparently this is a better approach to defining eras using pd.cut()
bins = [1950, 1952, 1954, 1959, 1968, 1978, 1983, 1989, 1997, 2006, 2009, 2014, 2025]
labels = [
    "Front engine era",
    "F2 era",
    "Front engine era (pt 2)",
    "Classic mid engine era",
    "Aero era",
    "Ground effects era",
    "Turbo era",
    "Naturally aspirated era",
    "V10 era",
    "V8 era",
    "Hybrid V8 era",
    "Hybrid V6 turbo era"
]

overall["era"] = pd.cut(overall["year"], bins=bins, labels=labels, right=False)

overall.head(25)
# Out:
#         resultId  driverId  constructorId number  grid position  \
# raceId
# 833        20025       642             51      2     1        1
# 833        20026       786             51      3     2        2
# 833        20027       686             51      4     4        3
# 833        20028       704            154     14     6        4
# 833        20029       627            154     15     9        5
# 833        20030       619            151     12    13        6
# 833        20031       787            151     11    15        7
# 833        20032       741            154     16    14        8
# 833        20033       784            105      6    16        9
# 833        20034       778            105     10    20       10
# 833        20177       788            105     10    20       10
# 833        20035       660            154     18    21       11
# 833        20036       579             51      1     3       \N
# ...

# %% [markdown]
# I want to plot which driver scored the most points for each era and colour by constructor. Ill use the modern points system to make it consistant. Best not to order the graph by total points scored because era years are inconsistant.

# %%
# ill export the overall table in case it gets altered in the future. I dont need to add any more columns right now.
overall.to_csv('overall.csv', index=False)

# %% [markdown]
# ### Why use era-adjusted Z-scores?
#
# Raw F1 statistics aren’t comparable across history due to changes in race counts, points systems and reliability. Era-adjusted Z-scores measure performance relative to competitors, not absolute totals. This allows fair comparison of dominance across different eras.
#
#
# ### How era-adjusted Z-scores work
#
# Points are converted to points per race for each driver within each era. Each driver’s performance is compared to the era average using a Z-score, where a higher Z-score means greater dominance relative to contemporaries.
#
# ### Era-adjusted Z-score formula
#
# $$
# Z_{\text{driver, era}} = \frac{\text{PPR}_{\text{driver, era}} - \mu_{\text{era}}}{\sigma_{\text{era}}}
# $$
#
#
# where:
# - PPR = points per race
# - μ = era mean points per race
# - σ = era standard deviation

# %%
# Right now each row = one race. We first need driver × era aggregates.
# This answers how many points per race did this driver score in this era?

driver_era = (
    overall.groupby(["driverId", "driverName", "era"])
      .agg(
          races=("resultId", "count"),
          total_points=("points", "sum") # points have already been converted to modern system
      )
      .reset_index()
)

# create column for PPR in the z-score formula
driver_era["points_per_race"] = (
    driver_era["total_points"] / driver_era["races"]
)
# Out:
# /var/folders/r8/fbhf1t_d7lq51r88zz03_blr0000gn/T/ipykernel_70694/2897526204.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   overall.groupby(["driverId", "driverName", "era"])

# %%
# Calculate the average and standard deviation of points per race
# for all drivers within each era (defines the era baseline)
era_stats = (
    driver_era.groupby("era")["points_per_race"]
    .agg(era_mean="mean", era_std="std")
    .reset_index()
)

# Attach each era's baseline statistics back onto the driver-level data
# so every driver can be compared to their era average
driver_era = driver_era.merge(
    era_stats,
    on="era",
    how="left"
)
# Out:
# /var/folders/r8/fbhf1t_d7lq51r88zz03_blr0000gn/T/ipykernel_70694/2154892090.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   driver_era.groupby("era")["points_per_race"]

# %%
# Apply the era adjusted z-score formula to the dataset and add as a column
driver_era["era_z_score"] = (
    (driver_era["points_per_race"] - driver_era["era_mean"])
    / driver_era["era_std"]
)


# 0.0 → average for that era
# +1.0 → elite
# +2.0 → historically dominant
# < −1.0 → below average
# This is now cross-era comparable.

driver_era = driver_era[driver_era["races"] >= 10] # drivers with a least 10 races
driver_era.head(20)
# Out:
#        driverId          driverName                  era  races  total_points  \
# 6285          1      Lewis Hamilton               V8 era     35         207.0
# 6286          1      Lewis Hamilton        Hybrid V8 era     94         895.0
# 6287          1      Lewis Hamilton  Hybrid V6 turbo era    227        3718.5
# 17684         2       Nick Heidfeld              V10 era     98          56.0
# 17685         2       Nick Heidfeld               V8 era     53         144.0
# 17686         2       Nick Heidfeld        Hybrid V8 era     33          59.0
# 28041         3        Nico Rosberg               V8 era     53          41.0
# 28042         3        Nico Rosberg        Hybrid V8 era     94         529.5
# 28043         3        Nico Rosberg  Hybrid V6 turbo era     59        1024.0
# 34076         4     Fernando Alonso              V10 era     70         247.0
# 34077         4     Fernando Alonso               V8 era     53         304.0
# ...

# %%
# Weight each driver's era-adjusted Z-score by the number of races
# This ensures that longer periods of dominance count more than short stints
career_scores = (
    driver_era.assign(
        weighted_z = driver_era["era_z_score"] * driver_era["races"]
    )

    # Combine all eras for each driver to get a single career score
    .groupby(["driverId", "driverName"])

    # Compute a weighted average Z-score across the driver's career:
    # sum of (Z-score × races) divided by total races
    .apply(lambda x: x["weighted_z"].sum() / x["races"].sum())

    # Rename the result to clearly show this is a career-level dominance metric
    .reset_index(name="career_era_z")
)
# Out:
# /var/folders/r8/fbhf1t_d7lq51r88zz03_blr0000gn/T/ipykernel_70694/262262334.py:13: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda x: x["weighted_z"].sum() / x["races"].sum())

# %%
career_scores
# Out:
#      driverId         driverName  career_era_z
# 0           1     Lewis Hamilton      2.920174
# 1           2      Nick Heidfeld      0.103120
# 2           3       Nico Rosberg      1.363258
# 3           4    Fernando Alonso      1.431420
# 4           5  Heikki Kovalainen     -0.242431
# ..        ...                ...           ...
# 348       855        Guanyu Zhou     -0.589010
# 349       856      Nyck de Vries     -0.602166
# 350       857      Oscar Piastri      1.208871
# 351       858     Logan Sargeant     -0.640061
# 352       859        Liam Lawson     -0.512708
#
# [353 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

# Top 20 drivers
top = career_scores.sort_values("career_era_z", ascending=False).head(20).copy()

# Determine each driver's primary era (most races in that era)
driver_primary_era = (
    driver_era.groupby(["driverName", "era"])["races"].sum()
    .reset_index()
    .sort_values(["driverName", "races"], ascending=[True, False])
    .drop_duplicates("driverName")
    .set_index("driverName")["era"]
)

top["primary_era"] = top["driverName"].map(driver_primary_era)

# Build a consistent color mapping for eras present in the top 20
eras = top["primary_era"].dropna().unique().tolist()
cmap = plt.get_cmap("tab20", len(eras))  # categorical colormap
era_to_color = {era: cmap(i) for i, era in enumerate(eras)}

colors = top["primary_era"].map(era_to_color).fillna("gray")

# Plot (fig, ax)
fig, ax = plt.subplots(figsize=(10, 6))

ax.barh(top["driverName"], top["career_era_z"], color=colors)
ax.axvline(0, linewidth=1)
ax.set_title("Top 20 Drivers by Era-Adjusted Performance")
ax.set_xlabel("Career Era Z-Score")
ax.invert_yaxis()

# Legend
handles = [
    plt.Line2D([0], [0], marker="s", linestyle="", markersize=10, color=era_to_color[era], label=era)
    for era in eras
]
ax.legend(handles=handles, title="Primary Era", bbox_to_anchor=(1.02, 1), loc="upper left")

plt.tight_layout()
plt.show()
# Out:
# /var/folders/r8/fbhf1t_d7lq51r88zz03_blr0000gn/T/ipykernel_70694/3134268428.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   driver_era.groupby(["driverName", "era"])["races"].sum()

# %% [markdown]
# Plot is showing that Juan Manuel Fangio was the most era-relative dominant driver in Formula 1 history. Thisll make an interesting discussion point, because now theres more dirivers, harder to become one etc. back in the 50s it was whoever was crazy enough to get into a car.

# %%
fig.savefig('figures/era_dominance.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# ## (slide 7) Fastest lap times for longest serving races like silverstone, monaco, monza etc.

# %% [markdown]
# The fastest laps aroudnd a circuit are going to be the laps recorderd in qualifying. We wont need to map driver id but i may as well anyways

# %%
import numpy as np

# load the dataset for qualifying
fastest_laps = pd.read_csv('data_raw/qualifying.csv')

# print(fastest_laps.dtypes)
# q1, q1, q3 are object types. need to convert to datetime to find min time.

print(fastest_laps.isna().any()[lambda x: x])
# showing that q2 and q3 have NaN values.

# The values missing arent NaN but an str /N. Ill make them NaN values
fastest_laps = fastest_laps.replace(r'\N', np.nan) # use r here for raw string. \ is normally escape character

# Replace the NaN values with the respective value from q1 column. This apparently has no nan values which would make sense
fastest_laps['q2'] = fastest_laps['q2'].fillna(fastest_laps['q1'])

# this works for making q2 time into q3 because i can tuse an if statement since that would return a bool.
fastest_laps['q3'] = fastest_laps['q3'].fillna(
    fastest_laps['q2'].fillna(fastest_laps['q1'])
)

fastest_laps.q3.dtype
display(fastest_laps)
# Out:
# q2    True
# q3    True
# dtype: bool
#        qualifyId  raceId  driverId  constructorId  number  position        q1  \
# 0              1      18         1              1      22         1  1:26.572
# 1              2      18         9              2       4         2  1:26.103
# 2              3      18         5              1      23         3  1:25.664
# 3              4      18        13              6       2         4  1:25.994
# 4              5      18         2              2       3         5  1:25.960
# ...          ...     ...       ...            ...     ...       ...       ...
# 10489      10547    1144       848              3      23        16  1:23.821
# 10490      10548    1144       855             15      24        17  1:23.880
# 10491      10549    1144         1            131      44        18  1:23.887
# 10492      10550    1144       861              3      43        19  1:23.912
# ...

# %%
# I now need to make a column for fastest lap for each driver in each race
cols = ['q1', 'q2', 'q3']
fastest_laps['best_quali_time'] = fastest_laps[cols].min(axis=1)
fastest_laps = fastest_laps.drop(columns=cols)

# Currently the data frame is labelled with ids. We want racenames and driver names.
# Load driver metadata, selecting and renaming to avoid name collisions
drivers = pd.read_csv('data_raw/drivers.csv')[['driverId', 'forename', 'surname']]
# create new column for full name
drivers['driverName'] = drivers['forename'] + ' ' + drivers['surname']
drivers = drivers[['driverId', 'driverName']]

# Merge driver info into results (avoid duplicate columns by using merge)
fastest_laps = fastest_laps.merge(drivers, on='driverId', how='inner')

# Load constructor and race metadata, selecting and renaming to avoid name collisions (this is all we need from these two csvs)
constructors = pd.read_csv('data_raw/constructors.csv')[['constructorId', 'name']].rename(columns={'name': 'constructorName'})
races = pd.read_csv('data_raw/races.csv')[['raceId', 'year', 'round', 'name']].rename(columns={'name': 'raceName'})

# Merge constructors and races into the overall dataset
fastest_laps = (fastest_laps
                .merge(constructors, on='constructorId', how='left')
                .merge(races, on='raceId', how='left')
                .drop(columns=['constructorId', 'driverId'])
                .sort_values(by=['year', 'round', 'position'])
                .set_index('raceId'))

fastest_laps

# Not sure what the earlierst year is. ill check
print(fastest_laps['year'].min(axis=0)) # will return max value of each column
# Apparently 1994. I could potentially do simialr methods to the racetimes from earlier years and use that as qualifying results?
# Out:
# 1994

# %%
fastest_laps
# Out:
#         qualifyId  number  position best_quali_time             driverName  \
# raceId
# 257          2594       2         1        1:15.962           Ayrton Senna
# 257          2595       5         2        1:16.290     Michael Schumacher
# 257          2596      27         3        1:17.385             Jean Alesi
# 257          2597       0         4        1:17.554             Damon Hill
# 257          2598      30         5        1:17.806  Heinz-Harald Frentzen
# ...           ...     ...       ...             ...                    ...
# 1144        10547      23        16        1:23.821        Alexander Albon
# 1144        10548      24        17        1:23.880            Guanyu Zhou
# 1144        10549      44        18        1:23.887         Lewis Hamilton
# 1144        10550      43        19        1:23.912       Franco Colapinto
# 1144        10551      61        20        1:24.105            Jack Doohan
#
#        constructorName  year  round              raceName
# ...

# %% [markdown]
# I could try web scraping for a few of the circuits that i want to analyse (Monaco, Monza). these two are pretty much unchanged so will be the best to see lap time evolution. Silverstone has changed lots. (for web scraping code, see f1_data_scraping.ipynb)

# %%
# we only want position 1 from the dataframe and to only have monaco and monza
monza = fastest_laps[
    (fastest_laps['position'] == 1) &
    (fastest_laps['raceName'].isin(['Italian Grand Prix']))
]

monza
# Out:
#         qualifyId  number  position best_quali_time          driverName  \
# raceId
# 268          2856      27         1        1:23.844          Jean Alesi
# 251          2450       6         1        1:24.462     David Coulthard
# 121          4021       1         1        1:20.963  Michael Schumacher
# 104          1399       2         1        1:20.089  Rubens Barrichello
# 85           1299       9         1        1:20.878      Kimi Räikkönen
# 67           1051       3         1        1:21.349      Kimi Räikkönen
# 48            633       1         1        1:21.356     Fernando Alonso
# 31            269      15         1        1:35.464    Sebastian Vettel
# 13           3226       1         1        1:22.973      Lewis Hamilton
# 350          3638       8         1        1:21.962     Fernando Alonso
# 853          5926       1         1        1:22.275    Sebastian Vettel
# 872          5252       4         1        1:24.010      Lewis Hamilton
# ...

# %% [markdown]
# ### Italian GP analysis

# %% [markdown]
# Both cirucits have had inconsistant track lengths. Especially monza when they had a combined circuit. For this reason, Average speed would be better than lap time as a metric. This is calculated by (distance travelled / lap time).

# %%
# Load the CSVs
italian_gp = pd.read_csv("italian_grand_prix_qualifying_1950_2025.csv")
italian_gp
# Out:
#      Pos.  No.          driverName                          Team  \
# 0       1   18  Juan Manuel Fangio                    Alfa Romeo
# 1       1   38  Juan Manuel Fangio                    Alfa Romeo
# 2       1   12      Alberto Ascari                       Ferrari
# 3       1    4      Alberto Ascari                       Ferrari
# 4       1   16  Juan Manuel Fangio                 Mercedes-Benz
# ...   ...  ...                 ...                           ...
# 1017   16   22        Yuki Tsunoda                 RB Honda RBPT
# 1018   17   18        Lance Stroll  Aston Martin Aramco Mercedes
# 1019   18   43    Franco Colapinto             Williams Mercedes
# 1020   19   77     Valtteri Bottas           Kick Sauber Ferrari
# 1021   20   24         Zhou Guanyu           Kick Sauber Ferrari
#
#      best_quali_time  Year  RaceId  Laps  Q1  Q2  Q3
# 0           1:58.600  1950     100   NaN NaN NaN NaN
# 1           1:53.200  1951     107   NaN NaN NaN NaN
# ...

# %%
# only select the drivers in position 1 (pole position)
italian_gp["Pos."] = pd.to_numeric(italian_gp["Pos."], errors="coerce")

# neet to remove indexes that repeat in years 1989,90,91 (200, 238, 272)
italian_gp = italian_gp[
    (italian_gp["Pos."] == 1) &
    (~italian_gp.index.isin([200, 238, 272]))
]
italian_gp
# Out:
#       Pos.  No.          driverName              Team best_quali_time  Year  \
# 0      1.0   18  Juan Manuel Fangio        Alfa Romeo        1:58.600  1950
# 1      1.0   38  Juan Manuel Fangio        Alfa Romeo        1:53.200  1951
# 2      1.0   12      Alberto Ascari           Ferrari        2:05.700  1952
# 3      1.0    4      Alberto Ascari           Ferrari        2:02.700  1953
# 4      1.0   16  Juan Manuel Fangio     Mercedes-Benz        1:59.000  1954
# ...    ...  ...                 ...               ...             ...   ...
# 922    1.0   44      Lewis Hamilton          Mercedes             NaN  2020
# 942    1.0   77     Valtteri Bottas          Mercedes             NaN  2021
# 962    1.0   16     Charles Leclerc           Ferrari             NaN  2022
# 982    1.0   55        Carlos Sainz           Ferrari             NaN  2023
# 1002   1.0    4        Lando Norris  McLaren Mercedes             NaN  2024
#
#       RaceId  Laps  Q1  Q2  Q3
# ...

# %%
# Make sure Year is consistent
monza["Year"] = monza["year"].astype(int)
italian_gp["Year"] = italian_gp["Year"].astype(int)

# Merge using an OUTER join so no years are lost
merged = pd.merge(
    monza,
    italian_gp,
    on="Year",
    how="outer",
    suffixes=("_monza", "_italian")
)

# Fill missing Monza values with Italian GP values
for col in merged.columns:
    if col.endswith("_monza"):
        base = col.replace("_monza", "")
        italian_col = f"{base}_italian"
        if italian_col in merged.columns:
            merged[base] = merged[col].combine_first(merged[italian_col])

# Keep only clean columns
cols_to_keep = ["Year"] + [
    c for c in merged.columns
    if not c.endswith("_monza") and not c.endswith("_italian") and c != "Year"
]

final_df = merged[cols_to_keep].sort_values("Year").reset_index(drop=True)

# Cant detect NaN values but only missing values. Ill just manually select the columns I want to use
final_df = final_df[['Year', 'No.', 'driverName', 'Team', 'best_quali_time']]
# Out:
# /var/folders/r8/fbhf1t_d7lq51r88zz03_blr0000gn/T/ipykernel_70694/2646154028.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   monza["Year"] = monza["year"].astype(int)
# /var/folders/r8/fbhf1t_d7lq51r88zz03_blr0000gn/T/ipykernel_70694/2646154028.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   italian_gp["Year"] = italian_gp["Year"].astype(int)

# %%
final_df
# Out:
#     Year  No.          driverName              Team best_quali_time
# 0   1950   18  Juan Manuel Fangio        Alfa Romeo        1:58.600
# 1   1951   38  Juan Manuel Fangio        Alfa Romeo        1:53.200
# 2   1952   12      Alberto Ascari           Ferrari        2:05.700
# 3   1953    4      Alberto Ascari           Ferrari        2:02.700
# 4   1954   16  Juan Manuel Fangio     Mercedes-Benz        1:59.000
# ..   ...  ...                 ...               ...             ...
# 70  2020   44      Lewis Hamilton          Mercedes        1:18.887
# 71  2021   77     Valtteri Bottas          Mercedes        1:19.555
# 72  2022   16     Charles Leclerc           Ferrari        1:20.161
# 73  2023   55        Carlos Sainz           Ferrari        1:20.294
# 74  2024    4        Lando Norris  McLaren Mercedes        1:19.327
#
# [75 rows x 5 columns]

# %%
# make a list of track lenghts to map to year

# year bins (left-inclusive, right-exclusive)
year_bins = [
    1950, 1955, 1957, 1960, 1962,
    1972, 1974, 1976,
    1994, 1996, 2000, 2025
]

# corresponding Monza F1 track lengths (km)
length_km = [
    6.300,  # 1950–1954  original GP circuit
    10.000, # 1955–1956  combined road + oval
    5.750,  # 1957–1959  road course
    10.000, # 1960–1961  combined road + oval
    5.750,  # 1962–1971  road course
    5.775,  # 1972–1973
    5.780,  # 1974–1975
    5.800,  # 1976–1993
    5.834,  # 1994–1995
    5.770,  # 1996–1999
    5.793   # 2000–2025
]


final_df['track_length_km'] = pd.cut(
    final_df['Year'],
    bins=year_bins,
    labels=length_km,
    right=False,
    ordered=False
).astype(float)

# %%
final_df
# Out:
#     Year  No.          driverName              Team best_quali_time  \
# 0   1950   18  Juan Manuel Fangio        Alfa Romeo        1:58.600
# 1   1951   38  Juan Manuel Fangio        Alfa Romeo        1:53.200
# 2   1952   12      Alberto Ascari           Ferrari        2:05.700
# 3   1953    4      Alberto Ascari           Ferrari        2:02.700
# 4   1954   16  Juan Manuel Fangio     Mercedes-Benz        1:59.000
# ..   ...  ...                 ...               ...             ...
# 70  2020   44      Lewis Hamilton          Mercedes        1:18.887
# 71  2021   77     Valtteri Bottas          Mercedes        1:19.555
# 72  2022   16     Charles Leclerc           Ferrari        1:20.161
# 73  2023   55        Carlos Sainz           Ferrari        1:20.294
# 74  2024    4        Lando Norris  McLaren Mercedes        1:19.327
#
#     track_length_km
# 0             6.300
# 1             6.300
# 2             6.300
# 3             6.300
# 4             6.300
# ..              ...
# ...

# %%
# convert best_quali_time (e.g., "1:23.844") to seconds, then compute km/h
def _to_seconds(val):
	s = str(val)
	if ':' in s:
		parts = s.split(':')
		if len(parts) == 2:  # M:SS.sss
			m, sec = parts
			return float(m) * 60 + float(sec)
	try:
		return float(s)  # plain seconds like "59.123"
	except ValueError:
		return np.nan

_quali_secs = final_df['best_quali_time'].apply(_to_seconds)

final_df['average_speed'] = final_df['track_length_km'] / (_quali_secs / 3600.0)  # km / (h) = km/h

# Remove 1980 as its an outlier due to the race not being held at monza that year
reduced_years = final_df[~final_df['Year'].isin([1980, 1998, 2008, 2017])].copy()

# %% [markdown]
# ### Plotting monza

# %%
import numpy as np
from matplotlib.lines import Line2D

fig, ax = plt.subplots(figsize=(12, 6))

ax.plot(
    reduced_years['Year'],
    reduced_years['average_speed'],
    marker='o',
    linestyle='-',
    color='blue'
)

# Plot points that werent included in red
outlier_years = final_df[final_df['Year'].isin([1998, 2008, 2017])]
ax.scatter(
    outlier_years['Year'],
    outlier_years['average_speed'],
    color='red',
    label='Non-Monza years'
)

ax.set_title('Average Speed of Pole Position at Italian Grand Prix (Monza)', size=16)
ax.set_xlabel('Year', size=14)
ax.set_ylabel('Average Speed (km/h)', size=14)
# ax.grid(True, linestyle='--', alpha=0.7)

# --- vertical markers: track/layout changes at Monza ---
track_changes = {
    1955: "Combined/oval era",
    1957: "Back to road",
    1960: "Combined returns",
    1962: "Road only",
    1972: "Chicanes added",
    1976: "2nd chicane era",
    1994: "Chicane changes",
    1996: "Layout tweak",
    2000: "Modern layout",
}

# --- track/layout changes ---
for year in track_changes:
    ax.axvline(
        year,
        linestyle=':',
        linewidth=1.5,
        alpha=0.7
    )

# --- vertical markers: major F1 regulation eras (optional) ---
reg_changes = {
    1966: "3.0L engines",
    1983: "Ground effect banned",
    1994: "Major safety rules",
    2009: "Aero overhaul",
    2014: "Hybrid era",
    2017: "Wider cars",
    2022: "Ground-effect return",
}

# --- regulation changes ---
for year in reg_changes:
    ax.axvline(
        year,
        linestyle='-',
        linewidth=1.2,
        alpha=0.4
    )

# Create legend manually
legend_elements = [
    Line2D(
        [0], [0],
        linestyle=':',
        linewidth=1.5,
        label='Monza track / layout change'
    ),
    Line2D(
        [0], [0],
        linestyle='-',
        linewidth=1.2,
        label='Major F1 regulation change'
    ),
    Line2D(
        [0], [0],
        marker='o',
        linestyle='-',
        color='blue',
        label='Pole position average speed'
    ),
    Line2D(
        [0], [0],
        marker='o',
        color='w',
        markerfacecolor='red',
        label='Wet qualifying years'
    )
]

ax.legend(
    handles=legend_elements,
    loc='lower right',
    frameon=True
)


# plt.xticks(reduced_years['Year'][::10], rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Drop in 1972 due to Monza adding Variante del Rettifilo (first chicane at the end of the main straight) and Variante Ascari (replacing the flat-out Ascari curve). These massively reduced average speed even though the circuit length barely changed.

# %%
fig.savefig('figures/italian_gp_pole_position_average_speed.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# ## (Slide 8) Monaco GP analysis of average speed

# %% [markdown]
# Dataframe should be the same from earlier

# %%
# we only want position 1 from the dataframe and to only have monaco and monza
monaco = fastest_laps[
    (fastest_laps['position'] == 1) &
    (fastest_laps['raceName'].isin(['Monaco Grand Prix']))
]

monaco
# Out:
#         qualifyId  number  position best_quali_time             driverName  \
# raceId
# 244          2280       5         1        1:21.952             Damon Hill
# 229          2134       1         1        1:20.356     Michael Schumacher
# 211          1897       4         1        1:18.216  Heinz-Harald Frentzen
# 114          3882       4         1        1:15.259        Ralf Schumacher
# 95           4181       7         1        1:13.985           Jarno Trulli
# 76           4519       9         1        1:13.644         Kimi Räikkönen
# 59            875       1         1        1:13.622        Fernando Alonso
# 40            457       1         1        1:15.431        Fernando Alonso
# 23            109       2         1        1:15.110           Felipe Massa
# 6            3086      22         1        1:14.902          Jenson Button
# 342          3446       6         1        1:13.826            Mark Webber
# ...

# %%
monaco_gp = pd.read_csv("monaco_grand_prix_qualifying_1950_2025.csv")
monaco_gp
# Out:
#     Pos.  No.          driverName                          Team  \
# 0      1   34  Juan Manuel Fangio                    Alfa Romeo
# 1      1    2  Juan Manuel Fangio                 Mercedes-Benz
# 2      1   20  Juan Manuel Fangio                       Ferrari
# 3      1   32  Juan Manuel Fangio                      Maserati
# 4      1   30         Tony Brooks                       Vanwall
# ..   ...  ...                 ...                           ...
# 982   14   14     Fernando Alonso  Aston Martin Aramco Mercedes
# 983   15    2      Logan Sargeant             Williams Mercedes
# 984   16   11        Sergio Perez    Red Bull Racing Honda RBPT
# 985   17   77     Valtteri Bottas           Kick Sauber Ferrari
# 986   18   24         Zhou Guanyu           Kick Sauber Ferrari
#
#     best_quali_time  Year  RaceId  Laps  Q1  Q2  Q3
# 0          1:50.200  1950      95   NaN NaN NaN NaN
# 1          1:41.100  1955     136   NaN NaN NaN NaN
# ...

# %%
# only select the drivers in position 1 (pole position)
monaco_gp["Pos."] = pd.to_numeric(monaco_gp["Pos."], errors="coerce")

# neet to remove indexes that repeat in years 1989,90,91 (200, 238, 272)
monaco_gp = monaco_gp[
    (monaco_gp["Pos."] == 1) &
    (~monaco_gp.index.isin([187, 225, 261, 293]))
]
monaco_gp
# Out:
#      Pos.  No.          driverName                        Team  \
# 0     1.0   34  Juan Manuel Fangio                  Alfa Romeo
# 1     1.0    2  Juan Manuel Fangio               Mercedes-Benz
# 2     1.0   20  Juan Manuel Fangio                     Ferrari
# 3     1.0   32  Juan Manuel Fangio                    Maserati
# 4     1.0   30         Tony Brooks                     Vanwall
# ..    ...  ...                 ...                         ...
# 888   1.0   44      Lewis Hamilton                    Mercedes
# 908   1.0   16     Charles Leclerc                     Ferrari
# 927   1.0   16     Charles Leclerc                     Ferrari
# 947   1.0    1      Max Verstappen  Red Bull Racing Honda RBPT
# 967   1.0   16     Charles Leclerc                     Ferrari
#
#     best_quali_time  Year  RaceId  Laps  Q1  Q2  Q3
# 0          1:50.200  1950      95   NaN NaN NaN NaN
# 1          1:41.100  1955     136   NaN NaN NaN NaN
# ...

# %%
# Make sure Year is consistent
monaco["Year"] = monaco["year"].astype(int)
italian_gp["Year"] = italian_gp["Year"].astype(int)

# Merge using an OUTER join so no years are lost
merged = pd.merge(
    monaco,
    monaco_gp,
    on="Year",
    how="outer",
    suffixes=("_monaco", "_monaco_gp")
)

# Fill missing Monaco values with Monaco GP values
for col in merged.columns:
    if col.endswith("_monaco"):
        base = col.replace("_monaco", "")
        monaco_gp_col = f"{base}_monaco_gp"
        if monaco_gp_col in merged.columns:
            merged[base] = merged[col].combine_first(merged[monaco_gp_col])
# Keep only clean columns
cols_to_keep = ["Year"] + [
    c for c in merged.columns
    if not c.endswith("_monaco") and not c.endswith("_monaco_gp") and c != "Year"
]

final_df_mon = merged[cols_to_keep].sort_values("Year").reset_index(drop=True)

# Cant detect NaN values but only missing values. Ill just manually select the columns I want to use
final_df_mon = final_df_mon[['Year', 'No.', 'driverName', 'Team', 'best_quali_time']]
# Out:
# /var/folders/r8/fbhf1t_d7lq51r88zz03_blr0000gn/T/ipykernel_70694/3572287933.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   monaco["Year"] = monaco["year"].astype(int)
# /var/folders/r8/fbhf1t_d7lq51r88zz03_blr0000gn/T/ipykernel_70694/3572287933.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   italian_gp["Year"] = italian_gp["Year"].astype(int)

# %%
final_df_mon
# Out:
#     Year  No.          driverName                        Team best_quali_time
# 0   1950   34  Juan Manuel Fangio                  Alfa Romeo        1:50.200
# 1   1955    2  Juan Manuel Fangio               Mercedes-Benz        1:41.100
# 2   1956   20  Juan Manuel Fangio                     Ferrari        1:44.000
# 3   1957   32  Juan Manuel Fangio                    Maserati        1:42.700
# 4   1958   30         Tony Brooks                     Vanwall        1:39.800
# ..   ...  ...                 ...                         ...             ...
# 65  2019   44      Lewis Hamilton                    Mercedes        1:10.166
# 66  2021   16     Charles Leclerc                     Ferrari        1:10.346
# 67  2022   16     Charles Leclerc                     Ferrari        1:11.376
# 68  2023    1      Max Verstappen  Red Bull Racing Honda RBPT        1:11.365
# 69  2024   16     Charles Leclerc                     Ferrari        1:10.270
#
# [70 rows x 5 columns]

# %%
# make a list of track lenghts to map to year

# year bins (left-inclusive, right-exclusive)
year_bins_monaco = [
    1950, 1955, 1973, 1976,
    1986, 1997, 2003, 2015, 2025
]

# corresponding Monaco F1 track lengths (km)
length_km_monaco = [
    3.180,  # 1950–1954  original layout
    3.145,  # 1955–1972  early revised layout
    3.278,  # 1973–1975  post-tunnel changes
    3.312,  # 1976–1985
    3.328,  # 1986–1996  Nouvelle Chicane era
    3.370,  # 1997–2002  Swimming Pool redesign
    3.340,  # 2003–2014
    3.337   # 2015–2024 (current layout)
]


final_df_mon['track_length_km'] = pd.cut(
    final_df_mon['Year'],
    bins=year_bins_monaco,
    labels=length_km_monaco,
    right=False,
    ordered=False
).astype(float)

# %%
# convert best_quali_time (e.g., "1:23.844") to seconds, then compute km/h
def _to_seconds(val):
	s = str(val)
	if ':' in s:
		parts = s.split(':')
		if len(parts) == 2:  # M:SS.sss
			m, sec = parts
			return float(m) * 60 + float(sec)
	try:
		return float(s)  # plain seconds like "59.123"
	except ValueError:
		return np.nan

_quali_secs = final_df_mon['best_quali_time'].apply(_to_seconds)

final_df_mon['average_speed'] = final_df_mon['track_length_km'] / (_quali_secs / 3600.0)  # km / (h) = km/h

# Remove 1980 as its an outlier due to the race not being held at monza that year
# reduced_years = final_df_mon[~final_df_mon['Year'].isin([])].copy()

# %%
final_df_mon
# Out:
#     Year  No.          driverName                        Team best_quali_time  \
# 0   1950   34  Juan Manuel Fangio                  Alfa Romeo        1:50.200
# 1   1955    2  Juan Manuel Fangio               Mercedes-Benz        1:41.100
# 2   1956   20  Juan Manuel Fangio                     Ferrari        1:44.000
# 3   1957   32  Juan Manuel Fangio                    Maserati        1:42.700
# 4   1958   30         Tony Brooks                     Vanwall        1:39.800
# ..   ...  ...                 ...                         ...             ...
# 65  2019   44      Lewis Hamilton                    Mercedes        1:10.166
# 66  2021   16     Charles Leclerc                     Ferrari        1:10.346
# 67  2022   16     Charles Leclerc                     Ferrari        1:11.376
# 68  2023    1      Max Verstappen  Red Bull Racing Honda RBPT        1:11.365
# 69  2024   16     Charles Leclerc                     Ferrari        1:10.270
#
# ...

# %% [markdown]
# ### Plotting Monaco

# %%
import numpy as np
from matplotlib.lines import Line2D

fig, ax = plt.subplots(figsize=(12, 6))

ax.plot(
    final_df_mon['Year'],
    final_df_mon['average_speed'],
    marker='o',
    linestyle='-',
    color='blue'
)

ax.set_title('Average Speed of Pole Position at Monaco Grand Prix', size=16)
ax.set_xlabel('Year', size=14)
ax.set_ylabel('Average Speed (km/h)', size=14)
# ax.grid(True, linestyle='--', alpha=0.7)

# vertical markers: track/layout changes at Monaco 
track_changes_monaco = {
    1950: "Original Monaco GP layout",
    1955: "Early revised layout",
    1973: "Tunnel & harbour changes",
    1976: "Pit / harbour reprofile",
    1986: "Nouvelle Chicane",
    1997: "Swimming Pool redesign",
    2003: "Minor layout revisions",
    2015: "Modern layout tweaks",
}

# track/layout changes 
for year in track_changes_monaco:
    ax.axvline(
        year,
        linestyle=':',
        linewidth=1.5,
        alpha=0.7
    )

# vertical markers: major F1 regulation eras (this should be the same as the previous plot)
reg_changes = {
    1966: "3.0L engines",
    1983: "Ground effect banned",
    1994: "Major safety rules",
    2009: "Aero overhaul",
    2014: "Hybrid era",
    2017: "Wider cars",
    2022: "Ground-effect return",
}

# regulation changes
for year in reg_changes:
    ax.axvline(
        year,
        linestyle='-',
        linewidth=1.2,
        alpha=0.4
    )

# Create legend manually
legend_elements = [
    Line2D(
        [0], [0],
        linestyle=':',
        linewidth=1.5,
        label='Monza track / layout change'
    ),
    Line2D(
        [0], [0],
        linestyle='-',
        linewidth=1.2,
        label='Major F1 regulation change'
    ),
    Line2D(
        [0], [0],
        marker='o',
        linestyle='-',
        label='Pole position average speed'
    )
]

ax.legend(
    handles=legend_elements,
    loc='lower right',
    frameon=True
)


# plt.xticks(reduced_years['Year'][::10], rotation=45)
plt.tight_layout()
plt.show()

# %%
fig.savefig('figures/monaco_gp_pole_position_average_speed.png', dpi=300, bbox_inches='tight')
